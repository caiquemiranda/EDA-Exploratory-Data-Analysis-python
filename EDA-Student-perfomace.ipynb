# %%
# importação das bibliotecas

import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import mpl, plt

# %%
# versões das bibliotecas

print(f'Versão Pandas :', pd.__version__)
print(f'Versão Numpy :', np.__version__)
print(f'Versão Matplotlib :', matplotlib.__version__)
print(f'Versão Seaborn :', sns.__version__)
# Out:
# Versão Pandas : 1.2.4
# Versão Numpy : 1.19.5
# Versão Matplotlib : 3.5.1
# Versão Seaborn : 0.11.1

# %%
# leitura de dados direto do github

students = pd.read_csv('https://raw.githubusercontent.com/caiquemiranda/EDA-Exploratory-Data-Analysis/main/data/StudentsPerformance.csv')

# %%
# leiura dos 5 primeiros registros

students.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# descrição estatística das colunas numércias

students.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# descrição estatística das colunas categóricas

students.describe(include=['O'])
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
# descrição estatística das colunas numéricas e categóricas

students.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %%
# informações sobre os dados

students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# contagem de valores nulos 

students.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# dicionario dos dados 1 

# numero de colunas e linhas
# tipo dos dados
# descrição das variaveis 
# valores nulos 
# anomalias

# %%
plt.rcParams['figure.figsize'] = (16,10)
plt.style.use('seaborn')
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.family'] = 'serif'

# %%
plt.subplot(221)
students['gender'].value_counts().plot(kind='bar', title='Gender of students', figsize=(20, 10))
plt.xticks(rotation=0)

plt.subplot(222)
students['race/ethnicity'].value_counts().plot(kind='bar', title='Race/ethnicity of students')
plt.xticks(rotation=0)

plt.subplot(223)
students['lunch'].value_counts().plot(kind='bar', title='Lunch status of students')
plt.xticks(rotation=0)

plt.subplot(224)
students['test preparation course'].value_counts().plot(kind='bar', title='Test preparation course')
plt.xticks(rotation=0);

# %%
plt.subplot(221)
students['gender'].value_counts().plot(kind='pie', title='Gender of students', autopct='%1.1f%%', figsize=(20, 10))
plt.xticks(rotation=0)

plt.subplot(222)
students['race/ethnicity'].value_counts().plot(kind='pie', title='Race/ethnicity of students', autopct='%1.1f%%')
plt.xticks(rotation=0)

plt.subplot(223)
students['lunch'].value_counts().plot(kind='pie', title='Lunch status of students', autopct='%1.1f%%')
plt.xticks(rotation=0)

plt.subplot(224)
students['test preparation course'].value_counts().plot(kind='pie', title='Test preparation course', autopct='%1.1f%%')
plt.xticks(rotation=0);

plt.show()

# %%
# visualização de variveis numericas em boxplot

students.boxplot()
plt.show()

# %%
# visualização de distribição de frequencia das variaveis numericas
# math score

sns.displot(students['math score'], kde=True)
plt.show()

# %%
sns.displot(students['reading score'], kde=True)
plt.show()

# %%
sns.displot(students['writing score'], kde=True)
plt.show()

# %%
corr =students.corr()
sns.heatmap(corr, annot=True,square=True)
plt.yticks(rotation=0)
plt.show()

# %%
sns.relplot(x='math score', y='writing score', hue = 'gender', data=students)
plt.show()

# %%
students.groupby('parental level of education')[['math score',  'reading score', 'writing score']].mean().T.plot(figsize = (12, 6))
plt.show()

# %%
students.groupby('test preparation course')[['math score', 'reading score', 'writing score']].mean().T.plot(kind='barh', figsize=(12,6))
plt.show()
